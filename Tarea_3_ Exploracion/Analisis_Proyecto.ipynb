# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy.stats import skew
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data (1).csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2459 entries, 0 to 2458
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2459 non-null   int64
#  1   host_id                         2459 non-null   int64
#  2   host_response_time              2459 non-null   object
#  3   host_response_rate              2459 non-null   float64
#  4   host_acceptance_rate            2459 non-null   float64
#  5   host_is_superhost               2459 non-null   int64
#  6   host_total_listings_count       2459 non-null   int64
#  7   host_has_profile_pic            2459 non-null   int64
#  8   host_identity_verified          2459 non-null   int64
#  9   neighbourhood_cleansed          2459 non-null   object
#  10  neighbourhood_group_cleansed    2459 non-null   object
#  11  latitude                        2459 non-null   float64
# ...

# %%
pd.set_option('display.max_columns', None)
data.head(10)
# Out:
#        id  host_id  host_response_time  host_response_rate  \
# 0   71896   367042  within a few hours            1.000000
# 1   71903   367042  within a few hours            1.000000
# 2  294281  1521514  within a few hours            1.000000
# 3  344803   367042  within a few hours            1.000000
# 4  369141  1521514  within a few hours            1.000000
# 5  369145  1521514  within a few hours            1.000000
# 6  468782  2327208  within a few hours            0.797932
# 7  747813  3926646  a few days or more            0.000000
# 8  747816  3926646  a few days or more            0.000000
# 9  765579  2413412  within a few hours            0.890000
#
#    host_acceptance_rate  host_is_superhost  host_total_listings_count  \
# 0              1.000000                  0                         10
# 1              1.000000                  0                         10
# 2              1.000000                  0                          8
# ...

# %%
plt.subplots(figsize=(15, 5))
sns.scatterplot(data=data, x="amenities_number", y="price", hue = 'neighbourhood_group_cleansed')
# Out:
# <Axes: xlabel='amenities_number', ylabel='price'>

# %%
sns.histplot(data = data, x = 'price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(data = data, y = 'price', x='neighbourhood_group_cleansed')
# Out:
# <Axes: xlabel='neighbourhood_group_cleansed', ylabel='price'>

# %%
data.price.describe()
# Out:
# count    2459.000000
# mean      231.223261
# std       162.929308
# min        20.000000
# 25%        89.000000
# 50%       200.000000
# 75%       325.500000
# max       750.000000
# Name: price, dtype: float64

# %%
sns.boxplot(data = data, y = 'price', x='amenities_number')
# Out:
# <Axes: xlabel='amenities_number', ylabel='price'>

# %%
sns.histplot(data = data, x = 'neighbourhood_group_cleansed')
# Out:
# <Axes: xlabel='neighbourhood_group_cleansed', ylabel='Count'>

# %%
plt.subplots(figsize=(15, 5))
sns.scatterplot(data=data, x="review_scores_rating", y="price")
# Out:
# <Axes: xlabel='review_scores_rating', ylabel='price'>

# %%
plt.subplots(figsize=(15, 5))
sns.scatterplot(data=data, x="review_scores_location", y="price", hue = 'room_type')
# Out:
# <Axes: xlabel='review_scores_location', ylabel='price'>

# %%
sns.boxplot(data = data, y = 'price')
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(data = data, y = 'price', x = 'room_type')
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
plt.subplots(figsize=(15, 5))
sns.scatterplot(data=data, x="number_of_private_bathrooms", y="price")
# Out:
# <Axes: xlabel='number_of_private_bathrooms', ylabel='price'>

# %%
sns.boxplot(data = data, y = 'price', x = 'number_of_private_bathrooms')
# Out:
# <Axes: xlabel='number_of_private_bathrooms', ylabel='price'>

# %%
plt.subplots(figsize=(15, 5))
sns.scatterplot(data=data, x="bedrooms", y="price")
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.boxplot(data = data, y = 'price', x = 'bedrooms')
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.boxplot(data = data, y = 'price', x = 'accommodates')
# Out:
# <Axes: xlabel='accommodates', ylabel='price'>

# %%
plt.subplots(figsize=(10, 5))
sns.scatterplot(data=data, x="bedrooms", y="price")
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
plt.subplots(figsize=(15, 5))
sns.scatterplot(data=data, x="beds", y="price")
# Out:
# <Axes: xlabel='beds', ylabel='price'>

# %%
sns.boxplot(data = data, y = 'price', x = 'beds')
# Out:
# <Axes: xlabel='beds', ylabel='price'>
